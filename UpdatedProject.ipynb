# %%
#Diabetes is a chronic and life-altering disease that can have lots of implications on a person 
#and affects how your body turns food into energy. An estimates 37.2 million people in the US
#have diabetes and that is over 11% of the population. This is a serious disease that needs prevention in the US
#with that being said I plan on working with the National Heath Association to find out what are early
#predictors of diabetes in women and how we can help prevent this. The importance of this project is to raise awareness
#to a very serious health problem with the use of analytics to help understand what causes diabetes.

#The way I broke down this problem is by first finding a dataset that shows patients with or without diabetes, and 
#factors that may have caused them to get diabetes. Once a dataset with a large sample size was collected I examined 
#these factors to help create visualizations to help solve the problem. This dataset is only women.

#I will now cover the findings and insights that I was able to conclude through the data 


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df1= pd.read_csv("diabetesdata1.csv")
df2= pd.read_csv("diabetesdata2.csv")
df= pd.merge(df1, df2, how='outer')


#I decided to use outer merge because I wanted to combine both the dataset into 1. Outer join
#allows you to do such as I had 2 datasets that needed to be merged. Instead of inner join
#which only shows the common dataset, outer join allows you to combine both into one

for i in df:
    data = df.copy()
    data[i].hist(bins=15)
    plt.xlabel(i)
    plt.ylabel("Sample Size(People)")
    plt.title(i)
    plt.show()
    
#This is my first visualization as well as an introduction to what I will be looking into. For this project I chose
#to work with the CDC and find ways to accurately predict what causes patients to go diabetes and how that can be 
#prevented. Below as you can see from the data we will be looking at a sample size of just women from the age range
#of 20-80. Below is the data that I will be digging further but is the data that will be used for the project. Below 
#are factors that can be associated with diabetes

# %%
#This is my second visualization as to what an early predictor of diabetes is. One of the biggest indicators that 
#a person may be diabetic with high glucose which inturn leads to higher insulin. 
#the pancreas produces insulin, a hormone that prompts cells to absorb blood sugar for energy or storage
#as you can see from the graph below the ones who have high glucose levels also have the higher insulin usually
#this is one thing patients must monitor for if they can potentially be diabetic

df.plot.scatter(x="Glucose", y="Insulin", alpha=0.5)
xlabel='Glucose'
plt.show()

#Now here are the results as you can see those with higher glucose and insulin are usually more 
#likely to be diabetic
sns.relplot(x='Glucose', y='Insulin', data=df, hue='Outcome')
plt.show()

# %%
#This is my third visualization. In this we have all the categories that are significant factors in terms
#of if a patient has diabetes or not. I am showing this graph to emphasize the importance that glucose levels have
#on whether a patient is diabetic or not. As u can see all the other categories have scattered values however, when we 
#look at glucose level there is a common trend that higher the glucose the more likely a person's diabetic. 

cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction']

for col in cols :
        plt.figure(figsize=(4,4))         
        sns.lmplot(x="Age", y=col, hue = "Outcome", data=df)   
plt.show()

# %%
#This is my fourth visualization. This was an interesting finding I found while conducting my research. In terms of age 
#being a factor in terms of if a patient is diabetic or not. What I found interesting is that patients around the 
#age of 45-55 are the ones that are most likely diabetic. This could be due to a variety of factors such as sample size,
#as the number of patients decreases as age does. Although this is the case, we see most of the diabetic patients
#come from this age group so as we age we need to be more cognizant.

plt.figure(figsize=(16,12))
cols = ['Age']
cnt=1
for col in cols :
        plt.subplot(3,3,cnt) 
        sns.histplot(x = col, data = df, hue = "Outcome")
        cnt= cnt+1
plt.tight_layout() 
plt.show()

#Group by aggregation to further prove the point and show how women from the age of 45-55 are most likely
#to get diabetes. This is shown as I only pull those 2 collums and make 'Age' the groupby and 'Outcome' the aggregate
df = pd.read_csv("diabetes.csv")
gk= df.groupby('Age').agg('Outcome')
gk.first()
# Out:
# Age
# 21    0
# 22    0
# 23    0
# 24    0
# 25    1
# 26    1
# 27    0
# 28    1
# 29    0
# 30    0
# 31    0
# 32    1
# 33    1
# 34    1
# 35    0
# 36    0
# 37    0
# 38    0
# 39    1
# 40    0
# 41    1
# 42    0
# 43    1
# 44    0
# 45    0
# 46    1
# 47    1
# 48    0
# 49    1
# 50    1
# 51    1
# 52    1
# 53    1
# 54    1
# 55    0
# 56    1
# 57    0
# 58    1
# 59    1
# 60    0
# 61    1
# 62    1
# 63    0
# 64    0
# 65    0
# 66    1
# 67    1
# 68    0
# 69    0
# 70    1
# 72    0
# 81    0
# Name: Outcome, dtype: int64

# %%
#This is my fifth visualization and I wanted to talk about the importance of BMI and diabetes. BMI is body mass index 
#Being overweight raises your risk for type 2 diabetes. If we look at the graph below we see a pretty obvious trend
#a patient with higher BMI is the most likely to be diabetic as you can see from the graph. This is to reiterate
#the importance of mentoring your weight as its a huge factor for being diabetic or not

fig = plt.figure(figsize=[15,4])
plt.subplot(1,2,2)
sns.histplot(data=df, hue='Outcome', x="BMI",kde=True)

plt.show()

# %%
#This is my sixth visualization and here we are looking at how pregnancy in women impacts diabetes. Since this is 
#data in just women this is important to talk about. As we can see from the graph pregnancies do not have much
#of an impact on being diabetic. One interesting thing to look at is that once a women had up to 6 pregnancies the 
#risk for diabetes goes up. We can see this as the number of diabetic patients are greater than the non diabetic from
#the pregnancy range of 6-9. This is something not many women take into consideration as most women are at much greater
#risk of being diabetic after 6+ pregnancies

plt.figure(figsize=(16,12))
cols = ['Pregnancies']
cnt=1
for col in cols :
        plt.subplot(3,3,cnt) 
        sns.histplot(x = col, data = df, hue = "Outcome")
        cnt= cnt+1
plt.tight_layout() 
plt.show()

#Groupby aggregation to further visualize the data and show how 6+ pregnancies put u at much higher risk of diabetes
#done by isolating pregnancy number and outcome
df = pd.read_csv("diabetes.csv")
gk= df.groupby('Pregnancies').agg('Outcome')
gk.first()
# Out:
# Pregnancies
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0
# 5     0
# 6     1
# 7     1
# 8     1
# 9     1
# 10    0
# 11    1
# 12    1
# 13    0
# 14    1
# 15    1
# 17    1
# Name: Outcome, dtype: int64

# %%
#Decision tree model also known as machine learning algorithm that will predict how accurate the model is in terms
#of if a patient has diabetes or not. The descision tree esentially asks a serires of questions untill it reaches
#a descision.

import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier #Decision Tree Model
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np
from sklearn.model_selection import train_test_split

X = df.iloc[:,0:8]
y = df['Outcome']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33 , random_state = 1)
clf = DecisionTreeClassifier(max_depth = 3)
clf = clf.fit(x_train , y_train)
y_pred = clf.predict(x_test)

print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.7204724409448819

# %%
#Random forest, also known as a machine learning algorithm that will also predict how accurate the model is. Just another
#way to predict the accuracy of the data. The random forest model creates a series of desicion trees which then
#those predictions are aggregated into a fianl prediction. As we can see the random forest model is a little more 
#accurate then the decision tree model. A decision tree combines decisions and a random forest combines several 
#decision trees. A decision tree is fast and operates easily on large data sets and random forest requires more 
#testing. Random forest is the more suitable algorithm as it provides more accurate results and is better for a larger data set like this. 


from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X = df.iloc[:,0:8]
y = df['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 1)
X_train.shape, X_test.shape
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)





print('Accuracy:', format(accuracy_score(y_test, y_pred)))

#As final recommendations, I recommend that all the things that I listed above be taken very seriously. As we have 
#understood from the graphs, there are specific indicators that can very much determine if you are at risk of diabetes
#and once these indicators are found, a patient can take action from there to resolve the issue. Early diagnosis is 
#key to diabetes prevention.

#Diabetes is only going to be on the rise around the world if people do not take action. This problem will always need
#to be revisited in the future as it is something that will never go away. As the years progress new data needs to be 
#collected to better come up with models that can help us predict this disease. If I was given more time and resources
#I would dive deeper into why actually certain indicators may or may not mean diabetes. I would also find ways to 
#better enahce the data so machine learning algorithms like the ones I made can produce better results.
# Out:
# Accuracy: 0.7834645669291339
